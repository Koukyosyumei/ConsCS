# %%
import os
import subprocess
import time
from misc import *

def run_and_log_and_solve_one_path(target_folder, file_path, log_path, log_path_with_contributions, flag_str, cur_max_depth):  
    if not file_path.endswith('.r1cs'):
        return
    assert len(flag_str) == 3
    assert isinstance(cur_max_depth, str)
    file_name = os.path.basename(file_path)
    base_name = file_name.split('.')[0]
    full_path = os.path.join(target_folder, file_path)
    target_file_path = full_path
    print(target_file_path)
    if os.path.exists(log_path):
        existing_log_contents = read_from_file(log_path)
        if f"** filename: {base_name}.circom" in existing_log_contents:
            assert f"** filename: {base_name}.circom" in read_from_file(log_path_with_contributions)
            return

    command = ["python3", "analyze_circuit.py", target_file_path, log_path, log_path_with_contributions, flag_str, cur_max_depth]
    try:
        result = subprocess.run(command, stdout=subprocess.PIPE, stderr=subprocess.PIPE, text=True)
    except Exception as e:
        log_message = ""
        log_message += f"** filename: {base_name}.circom \n"
        log_message += f"** result: {message} \n"
        log_message += f"** time: {time_taken} \n"
        append_log(log_message, log_path)
        
        
    if result.stdout:
        print("Output:", result.stdout)
    if result.stderr:
        print("Error:", result.stderr)


# ablation
for SIMPLIFICATION_flag in ["1", "0"]:
    for BPG_flag in ["1", "0"]:
        for ASSUMPTION_flag in ["1", "0"]:
            flag_str = SIMPLIFICATION_flag + BPG_flag + ASSUMPTION_flag
            cur_max_depth = '4'
            print(flag_str, cur_max_depth)
            
            log_path = f"./logs/our_logs_{flag_str}_{cur_max_depth}.log"
            log_path_with_contributions = f"./logs/our_logs_with_contributions_{flag_str}_{cur_max_depth}.log"
            for type_folder in ["circomlibex-cff5ab6", "circomlib-cff5ab6"]:
                target_folder = os.path.join("./picus_bench/", type_folder)
                for file_path in os.listdir(target_folder):
                    run_and_log_and_solve_one_path(target_folder, file_path, log_path, log_path_with_contributions, flag_str, cur_max_depth)

                    
                    
# testing depth                 
for cur_max_depth in range(10):
    cur_max_depth = str(cur_max_depth)
    if cur_max_depth == '4':
        continue
    flag_str = '111'
    
    print(flag_str, cur_max_depth)

    log_path = f"./logs/our_logs_{flag_str}_{cur_max_depth}.log"
    log_path_with_contributions = f"./logs/our_logs_with_contributions_{flag_str}_{cur_max_depth}.log"
    for type_folder in ["utils", "core"]:
        target_folder = os.path.join("./picus_bench/", type_folder)
        for file_path in os.listdir(target_folder):
            run_and_log_and_solve_one_path(target_folder, file_path, log_path, log_path_with_contributions, flag_str, cur_max_depth)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In [2], line 100
#      97 log_path = "./logs/our_logs.log"
#      98 log_path_with_contributions = "./logs/our_logs_with_contributions.log"
# --> 100 write_to_file("", log_path)
#     101 write_to_file("", log_path_with_contributions)
#     104 for type_folder in ["circomlibex-cff5ab6", "circomlib-cff5ab6"]:
#
# File ~/Documents/Faster_picus/JINAN/final_utils_for_paper_misc.py:136, in write_to_file(contents, path)
#     135 def write_to_file(contents, path):
# --> 136     with open(path, 'w') as f:
#     137         f.write(contents)
#
# FileNotFoundError: [Errno 2] No such file or directory: './logs/our_logs.log'

# %%
bool('0')
# Out:
# True

# %%
from multiprocessing import Pool
import multiprocessing

# %%
    # TODO: look it up
    # Use ThreadPoolExecutor to handle the timeout
    with concurrent.futures.ThreadPoolExecutor(max_workers=1) as executor:
        future = executor.submit(grobner_basis_helper, polynomials, grobner_method)
        try:
            G = future.result(timeout=timeout)  # waits for the function to return or timeout
            grobner_found = True
        except concurrent.futures.TimeoutError:
            print(timeout)
            return None, None

# %%
import os
import subprocess
import time
from misc import *

def run_and_log_and_solve_one_path(target_folder, file_path, log_path, log_path_with_contributions, flag_str, cur_max_depth):  
    if not file_path.endswith('.r1cs'):
        return
    assert len(flag_str) == 3
    assert isinstance(cur_max_depth, str)
    file_name = os.path.basename(file_path)
    base_name = file_name.split('.')[0]
    full_path = os.path.join(target_folder, file_path)
#     log_file_path = os.path.join(log_path, f'{base_name}.log')
    target_file_path = full_path
    print(target_file_path)
    if os.path.exists(log_path):
        existing_log_contents = read_from_file(log_path)
        if f"** filename: {base_name}.circom" in existing_log_contents:
            assert f"** filename: {base_name}.circom" in read_from_file(log_path_with_contributions)
            return

#     command = f"python3 analyze_circuit.py {target_file_path} {log_path} {log_path_with_contributions}"
#     process = subprocess.Popen(command, shell=True, stdout=subprocess.PIPE, stderr=subprocess.PIPE)
    command = ["python3", "analyze_circuit.py", target_file_path, log_path, log_path_with_contributions, flag_str, cur_max_depth]
    result = subprocess.run(command, stdout=subprocess.PIPE, stderr=subprocess.PIPE, text=True)

    # Optionally, handle the outputs
    if result.stdout:
        print("Output:", result.stdout)
    if result.stderr:
        print("Error:", result.stderr)


# log_path = "./logs/our_logs.log"
# log_path_with_contributions = "./logs/our_logs_with_contributions.log"

# write_to_file("", log_path)
# write_to_file("", log_path_with_contributions)

# for type_folder in ["circomlibex-cff5ab6", "circomlib-cff5ab6"]:
#     target_folder = os.path.join("./picus_bench/", type_folder)
#     for file_path in os.listdir(target_folder):
#         run_and_log_and_solve_one_path(target_folder, file_path, log_path, log_path_with_contributions)
                    

flag_str = '111'
cur_max_depth = '4'
print(flag_str, cur_max_depth)

log_path = f"./logs/full_contribution_{flag_str}_{cur_max_depth}.log"
log_path_with_contributions = f"./logs/full_contribution__with_contributions_{flag_str}_{cur_max_depth}.log"
for type_folder in ["circomlibex-cff5ab6", "circomlib-cff5ab6"]:
    target_folder = os.path.join("./picus_bench/", type_folder)
    for file_path in os.listdir(target_folder):
        run_and_log_and_solve_one_path(target_folder, file_path, log_path, log_path_with_contributions, flag_str, cur_max_depth)

# %%
import os
import subprocess
import time
from misc import *

def run_and_log_and_solve_one_path(target_folder, file_path, log_path, log_path_with_contributions, flag_str, cur_max_depth):  
    if not file_path.endswith('.r1cs'):
        return
    assert len(flag_str) == 3
    assert isinstance(cur_max_depth, str)
    file_name = os.path.basename(file_path)
    base_name = file_name.split('.')[0]
    full_path = os.path.join(target_folder, file_path)
#     log_file_path = os.path.join(log_path, f'{base_name}.log')
    target_file_path = full_path
    print(target_file_path)
    if os.path.exists(log_path):
        existing_log_contents = read_from_file(log_path)
        if f"** filename: {base_name}.circom" in existing_log_contents:
            assert f"** filename: {base_name}.circom" in read_from_file(log_path_with_contributions)
            return

#     command = f"python3 analyze_circuit.py {target_file_path} {log_path} {log_path_with_contributions}"
#     process = subprocess.Popen(command, shell=True, stdout=subprocess.PIPE, stderr=subprocess.PIPE)
    command = ["python3", "analyze_circuit.py", target_file_path, log_path, log_path_with_contributions, flag_str, cur_max_depth, '1']
    result = subprocess.run(command, stdout=subprocess.PIPE, stderr=subprocess.PIPE, text=True)

    # Optionally, handle the outputs
    if result.stdout:
        print("Output:", result.stdout)
    if result.stderr:
        print("Error:", result.stderr)


# log_path = "./logs/our_logs.log"
# log_path_with_contributions = "./logs/our_logs_with_contributions.log"

# write_to_file("", log_path)
# write_to_file("", log_path_with_contributions)

# for type_folder in ["circomlibex-cff5ab6", "circomlib-cff5ab6"]:
#     target_folder = os.path.join("./picus_bench/", type_folder)
#     for file_path in os.listdir(target_folder):
#         run_and_log_and_solve_one_path(target_folder, file_path, log_path, log_path_with_contributions)
                    

flag_str = '111'
cur_max_depth = '4'
print(flag_str, cur_max_depth)

log_path = f"./logs/no_clause_learning_{flag_str}_{cur_max_depth}.log"
log_path_with_contributions = f"./logs/no_clause_learning_with_contributions_{flag_str}_{cur_max_depth}.log"
for type_folder in ["circomlibex-cff5ab6", "circomlib-cff5ab6"]:
    target_folder = os.path.join("./picus_bench/", type_folder)
    for file_path in os.listdir(target_folder):
        run_and_log_and_solve_one_path(target_folder, file_path, log_path, log_path_with_contributions, flag_str, cur_max_depth)

# %%
./picus_bench/circomlibex-cff5ab6/Bits2Point_Strict@pointbits@circomlib.r1cs
2589 constraints, 257 inputs, 2 outputs.
doing edge id
trying method 1
Traceback (most recent call last):
  File "/media/Disk8T/jinan/compiling_circom/Picus/run_ours.py", line 129, in <module>
    message, time_taken = solve_one_path(base_name, target_file_path)
  File "/media/Disk8T/jinan/compiling_circom/Picus/run_ours.py", line 67, in solve_one_path
    found_UNDER, affected_vars, counterexample = try_assumptions_smt(r1cs_circuit, timeout_assumptions_smt)
  File "/media/Disk8T/jinan/compiling_circom/Picus/final_util_for_paper.py", line 152, in try_assumptions_smt
    G, l_expr = get_grobner_basis(r1cs_circuit, with_hypothesis = edge, timeout=5, grobner_method = grobner_method)
  File "/media/Disk8T/jinan/compiling_circom/Picus/final_util_for_paper.py", line 440, in get_grobner_basis
    polynomials.append(get_sympy_expression_of_sdp(SingleDotProduct(with_hypothesis.condition)))
  File "/media/Disk8T/jinan/compiling_circom/Picus/final_util_for_paper.py", line 310, in get_sympy_expression_of_sdp
    poly = Poly(final_expression, domain=GF(p))
  File "/media/Disk8T/jinan/compiling_circom/Picus/cur_env/lib/python3.10/site-packages/sympy/polys/polytools.py", line 182, in __new__
    return cls._from_expr(rep, opt)
  File "/media/Disk8T/jinan/compiling_circom/Picus/cur_env/lib/python3.10/site-packages/sympy/polys/polytools.py", line 312, in _from_expr
    return cls._from_dict(rep, opt)
  File "/media/Disk8T/jinan/compiling_circom/Picus/cur_env/lib/python3.10/site-packages/sympy/polys/polytools.py", line 249, in _from_dict
    raise GeneratorsNeeded(
sympy.polys.polyerrors.GeneratorsNeeded: Cannot initialize from 'dict' without generators

        
        
    issue with:
        if with_hypothesis is not None:
#         if with_hypothesis.target not in var_order:
#             var_order.append(int(with_hypothesis.target))
        polynomials.append(get_sympy_expression_of_sdp(SingleDotProduct(with_hypothesis.condition)))

# %%
import os
import subprocess
import time
from misc import *

def run_and_log_and_solve_one_path(target_folder, file_path, log_path, log_path_with_contributions, flag_str, cur_max_depth):  
    if not file_path.endswith('.r1cs'):
        return
    assert len(flag_str) == 3
    assert isinstance(cur_max_depth, str)
    file_name = os.path.basename(file_path)
    base_name = file_name.split('.')[0]
    full_path = os.path.join(target_folder, file_path)
#     log_file_path = os.path.join(log_path, f'{base_name}.log')
    target_file_path = full_path
    print(target_file_path)
    if os.path.exists(log_path):
        existing_log_contents = read_from_file(log_path)
        if f"** filename: {base_name}.circom" in existing_log_contents:
            assert f"** filename: {base_name}.circom" in read_from_file(log_path_with_contributions)
            return

#     command = f"python3 analyze_circuit.py {target_file_path} {log_path} {log_path_with_contributions}"
#     process = subprocess.Popen(command, shell=True, stdout=subprocess.PIPE, stderr=subprocess.PIPE)
    command = ["python3", "analyze_circuit.py", target_file_path, log_path, log_path_with_contributions, flag_str, cur_max_depth]
    result = subprocess.run(command, stdout=subprocess.PIPE, stderr=subprocess.PIPE, text=True)

    # Optionally, handle the outputs
    if result.stdout:
        print("Output:", result.stdout)
    if result.stderr:
        print("Error:", result.stderr)



flag_str = '111'
cur_max_depth = '4'
print(flag_str, cur_max_depth)

log_path = f"./logs/our_logs_{flag_str}_{cur_max_depth}.log"
log_path_with_contributions = f"./logs/our_logs_with_contributions_{flag_str}_{cur_max_depth}.log"
for type_folder in ["circomlibex-cff5ab6", "circomlib-cff5ab6"]:
    target_folder = os.path.join("./picus_bench/", type_folder)
    for file_path in os.listdir(target_folder):
        run_and_log_and_solve_one_path(target_folder, file_path, log_path, log_path_with_contributions, flag_str, cur_max_depth)

# %%
import os
import subprocess
import time
from misc import *

def run_and_log_and_solve_one_path(target_folder, file_path, log_path, log_path_with_contributions, flag_str, cur_max_depth):  
    if not file_path.endswith('.r1cs'):
        return
    assert len(flag_str) == 3
    assert isinstance(cur_max_depth, str)
    file_name = os.path.basename(file_path)
    base_name = file_name.split('.')[0]
    full_path = os.path.join(target_folder, file_path)
#     log_file_path = os.path.join(log_path, f'{base_name}.log')
    target_file_path = full_path
    print(target_file_path)
    if os.path.exists(log_path):
        existing_log_contents = read_from_file(log_path)
        if f"** filename: {base_name}.circom" in existing_log_contents:
            assert f"** filename: {base_name}.circom" in read_from_file(log_path_with_contributions)
            return

#     command = f"python3 analyze_circuit.py {target_file_path} {log_path} {log_path_with_contributions}"
#     process = subprocess.Popen(command, shell=True, stdout=subprocess.PIPE, stderr=subprocess.PIPE)
    command = ["python3", "analyze_circuit.py", target_file_path, log_path, log_path_with_contributions, flag_str, cur_max_depth]
    result = subprocess.run(command, stdout=subprocess.PIPE, stderr=subprocess.PIPE, text=True)

    # Optionally, handle the outputs
    if result.stdout:
        print("Output:", result.stdout)
    if result.stderr:
        print("Error:", result.stderr)


# log_path = "./logs/our_logs.log"
# log_path_with_contributions = "./logs/our_logs_with_contributions.log"

# write_to_file("", log_path)
# write_to_file("", log_path_with_contributions)

# for type_folder in ["circomlibex-cff5ab6", "circomlib-cff5ab6"]:
#     target_folder = os.path.join("./picus_bench/", type_folder)
#     for file_path in os.listdir(target_folder):
#         run_and_log_and_solve_one_path(target_folder, file_path, log_path, log_path_with_contributions)
                    

# ablation
for SIMPLIFICATION_flag in ["1", "0"]:
    for BPG_flag in ["1", "0"]:
        ASSUMPTION_flag = '0'
        flag_str = SIMPLIFICATION_flag + BPG_flag + ASSUMPTION_flag
        cur_max_depth = '4'
        print(flag_str, cur_max_depth)

        log_path = f"./logs/our_logs_{flag_str}_{cur_max_depth}.log"
        log_path_with_contributions = f"./logs/our_logs_with_contributions_{flag_str}_{cur_max_depth}.log"
        for type_folder in ["circomlibex-cff5ab6", "circomlib-cff5ab6"]:
            target_folder = os.path.join("./picus_bench/", type_folder)
            for file_path in os.listdir(target_folder):
                run_and_log_and_solve_one_path(target_folder, file_path, log_path, log_path_with_contributions, flag_str, cur_max_depth)

# %%
import os
import subprocess
import time
from misc import *

def run_and_log_and_solve_one_path(target_folder, file_path, log_path, log_path_with_contributions, flag_str, cur_max_depth):  
    if not file_path.endswith('.r1cs'):
        return
    assert len(flag_str) == 3
    assert isinstance(cur_max_depth, str)
    file_name = os.path.basename(file_path)
    base_name = file_name.split('.')[0]
    full_path = os.path.join(target_folder, file_path)
#     log_file_path = os.path.join(log_path, f'{base_name}.log')
    target_file_path = full_path
    print(target_file_path)
    if os.path.exists(log_path):
        existing_log_contents = read_from_file(log_path)
        if f"** filename: {base_name}.circom" in existing_log_contents:
            assert f"** filename: {base_name}.circom" in read_from_file(log_path_with_contributions)
            return

#     command = f"python3 analyze_circuit.py {target_file_path} {log_path} {log_path_with_contributions}"
#     process = subprocess.Popen(command, shell=True, stdout=subprocess.PIPE, stderr=subprocess.PIPE)
    command = ["python3", "analyze_circuit.py", target_file_path, log_path, log_path_with_contributions, flag_str, cur_max_depth, ]
    result = subprocess.run(command, stdout=subprocess.PIPE, stderr=subprocess.PIPE, text=True)

    # Optionally, handle the outputs
    if result.stdout:
        print("Output:", result.stdout)
    if result.stderr:
        print("Error:", result.stderr)



flag_str = '111'
cur_max_depth = '4'
print(flag_str, cur_max_depth)

log_path = f"./logs/our_logs_{flag_str}_{cur_max_depth}.log"
log_path_with_contributions = f"./logs/our_logs_with_contributions_{flag_str}_{cur_max_depth}.log"
for type_folder in ["circomlibex-cff5ab6", "circomlib-cff5ab6"]:
    target_folder = os.path.join("./picus_bench/", type_folder)
    for file_path in os.listdir(target_folder):
        run_and_log_and_solve_one_path(target_folder, file_path, log_path, log_path_with_contributions, flag_str, cur_max_depth)

# %%
import os
import subprocess
import time
from misc import *

def run_and_log_and_solve_one_path(target_folder, file_path, log_path, log_path_with_contributions, flag_str, cur_max_depth):  
    if not file_path.endswith('.r1cs'):
        return
    assert len(flag_str) == 3
    assert isinstance(cur_max_depth, str)
    file_name = os.path.basename(file_path)
    base_name = file_name.split('.')[0]
    full_path = os.path.join(target_folder, file_path)
#     log_file_path = os.path.join(log_path, f'{base_name}.log')
    target_file_path = full_path
    print(target_file_path)
    if os.path.exists(log_path):
        existing_log_contents = read_from_file(log_path)
        if f"** filename: {base_name}.circom" in existing_log_contents:
            assert f"** filename: {base_name}.circom" in read_from_file(log_path_with_contributions)
            return

#     command = f"python3 analyze_circuit.py {target_file_path} {log_path} {log_path_with_contributions}"
#     process = subprocess.Popen(command, shell=True, stdout=subprocess.PIPE, stderr=subprocess.PIPE)
    command = ["python3", "analyze_circuit.py", target_file_path, log_path, log_path_with_contributions, flag_str, cur_max_depth]
    result = subprocess.run(command, stdout=subprocess.PIPE, stderr=subprocess.PIPE, text=True)

    # Optionally, handle the outputs
    if result.stdout:
        print("Output:", result.stdout)
    if result.stderr:
        print("Error:", result.stderr)



flag_str = '111'
cur_max_depth = '4'
print(flag_str, cur_max_depth)

log_path = f"./logs/our_logs_{flag_str}_{cur_max_depth}_smthits.log"
log_path_with_contributions = f"./logs/our_logs_with_contributions_{flag_str}_{cur_max_depth}_smthits.log"
for type_folder in ["circomlibex-cff5ab6", "circomlib-cff5ab6"]:
    target_folder = os.path.join("./picus_bench/", type_folder)
    for file_path in os.listdir(target_folder):
        run_and_log_and_solve_one_path(target_folder, file_path, log_path, log_path_with_contributions, flag_str, cur_max_depth)
